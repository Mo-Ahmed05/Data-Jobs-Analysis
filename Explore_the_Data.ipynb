# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import Data

# %% [markdown]
# # Loading... Data

# %%
# Copy of the main DataFrame
df = Data.DF.copy()

# %%
# Data informations
df.info()
df.sample(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
#  17  yearly_salary_avg      32665 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(3), object(11)
# memory usage: 92.2+ MB
#               job_title_short  \
# 222760    Senior Data Analyst
# 698250         Data Scientist
# 375993  Senior Data Scientist
#
#                                                 job_title       job_location  \
# 222760  Senior Fraud Data Analyst (681175) // US or GC...     Washington, DC
# 698250                                     Data Scientist  Duisburg, Germany
# 375993                              Data Scientist Senior      United States
#
#                       job_via job_schedule_type  job_work_from_home  \
# 222760           via LinkedIn         Full-time               False
# 698250  via BeBee Deutschland         Full-time               False
# 375993              via BeBee         Full-time               False
#
#                 search_location     job_posted_date  job_no_degree_mention  \
# 222760  New York, United States 2023-04-12 22:00:20                  False
# 698250                  Germany 2023-01-27 03:24:27                  False
# 375993  Illinois, United States 2023-10-09 18:27:18                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 222760                 False  United States        hour              NaN
# 698250                 False        Germany        None              NaN
# 375993                 False  United States        None              NaN
#
#         salary_hour_avg                 company_name  \
# 222760            107.5     Dantech Corporation Inc.
# 698250              NaN  PKF Fasselt Consulting GmbH
# 375993              NaN       Stanley Reid & Company
#
#                                                job_skills  \
# 222760  [sql, sas, sas, snowflake, tableau, ssrs, look...
# 698250                                                NaN
# 375993                               [python, tensorflow]
#
#                                           job_type_skills  yearly_salary_avg
# 222760  {'analyst_tools': ['sas', 'tableau', 'ssrs', '...           223600.0
# 698250                                               None                NaN
# 375993  {'libraries': ['tensorflow'], 'programming': [...                NaN

# %% [markdown]
# Cleaning Data

# %%
# Cleaning the date column
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %% [markdown]
# # Visualizations

# %% [markdown]
# What countries does the dataset depend on?

# %%
countries = df['job_country'].value_counts().nlargest(15).to_frame()

sns.set_theme()
sns.barplot(data=countries, x='count', y=countries.index, hue='count', legend=False, palette='dark:b_r')

plt.gca().xaxis.set_major_formatter(mtick.FuncFormatter(lambda x, pos: format(int(x), ",")))

plt.title('Top 15 Countries in Dataset', fontweight='bold', size=16)
plt.ylabel('')
plt.xlabel('No. of Jobs Postings')

plt.show()

# %% [markdown]
# What jobs does the dataset depend on?

# %%
jobs = df['job_title_short'].value_counts().to_frame()

sns.set_theme()
sns.barplot(data=jobs, x='count', y=jobs.index, hue='count', legend=False, palette='dark:b_r')

plt.gca().xaxis.set_major_formatter(mtick.FuncFormatter(lambda x, pos: format(int(x), ",")))

plt.title('Jobs Postings in the Dataset', fontweight='bold', size=16)
plt.ylabel('')
plt.xlabel('No. of Jobs Postings')

plt.show()

# %% [markdown]
# What is the date of the dataset?

# %%
date = df['job_posted_date'].dt.strftime('%Y-%m').value_counts().to_frame()
date.reset_index(inplace=True)
date.sort_values(by='job_posted_date', inplace=True)

sns.set_theme()
sns.lineplot(data=date, x='job_posted_date', y='count')

plt.gca().yaxis.set_major_formatter(mtick.FuncFormatter(lambda y, pos: format(int(y), ",")))
plt.xticks(rotation=30)

plt.title('Date of the Dataset', fontweight='bold', size=16)
plt.ylabel('')
plt.xlabel('')

plt.show()

# %% [markdown]
# Yearly Salary VS Hourly Salary

# %%
salary_rate = df[(df['salary_rate'] == 'year') | (df['salary_rate'] == 'hour')]['salary_rate'].value_counts()

salary_rate.plot(
    kind='bar',
    color=["#3d4a60",'#6784b0']
)

plt.title('Salary Rate Distribution', fontweight='bold', size=16)
plt.xlabel('Salary Rate Type')
plt.ylabel('Job Postings Count')
plt.xticks(rotation=0)
plt.show()



total = len(df)
valid = df['salary_rate'].isin(['year', 'hour']).sum()
missing = total - valid

print(f"Note: {(missing / total) * 100:.1f}% has no valid salary rate")
# Out:
# Note: 95.8% has no valid salary rate
